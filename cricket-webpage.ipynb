# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
import os
fname=[]
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if(dirname=='/kaggle/input/cricsheet-a-retrosheet-for-cricket/t20s'):
            fname.append(os.path.join(dirname, filename))

# %%
len(fname)
# Out:
# 1433

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(fname):
    try:
        with open(file, 'r') as f:
            df = pd.json_normalize(safe_load(f))
            df['match_id'] = counter
            final_df = final_df.append(df)
            counter+=1
    except NotImplementedError:
        print("Error")
            
final_df
# Out:
#  44%|████▍     | 637/1433 [03:38<04:03,  3.27it/s]
# Error
# 100%|██████████| 1433/1433 [08:11<00:00,  2.91it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Nigeria', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
#
#    meta.created  meta.revision      info.city    info.dates info.gender  \
# 0    2012-12-30              2        Belfast  [2008-08-04]        male
# 0    2020-08-08              1      Abu Dhabi  [2017-10-27]        male
# 0    2020-07-06              1            NaN  [2018-07-05]        male
# 0    2020-07-01              1         Guyana  [2018-11-11]      female
# 0    2020-03-06              1  Greater Noida  [2020-03-06]        male
# ..          ...            ...            ...           ...         ...
# 0    2019-10-25              1      Abu Dhabi  [2019-10-24]        male
# 0    2020-08-08              1            NaN  [2017-11-12]      female
# 0    2013-02-20              2       Auckland  [2006-12-26]        male
# 0    2014-05-25              2            NaN  [2012-10-31]      female
# 0    2019-11-14              1        Lucknow  [2019-11-14]        male
#
#    info.match_type  info.neutral_venue  info.outcome.by.wickets  ... match_id  \
# 0              T20                 1.0                      5.0  ...        1
# 0              T20                 NaN                      2.0  ...        2
# 0              T20                 NaN                      NaN  ...        3
# 0              T20                 NaN                      9.0  ...        4
# 0              T20                 NaN                      NaN  ...        5
# ..             ...                 ...                      ...  ...      ...
# 0              T20                 NaN                      5.0  ...     1428
# 0              T20                 NaN                      NaN  ...     1429
# 0              T20                 NaN                      5.0  ...     1430
# 0              T20                 1.0                      NaN  ...     1431
# 0              T20                 NaN                      NaN  ...     1432
#
#     info.match_type_number info.outcome.by.runs info.outcome.method  \
# 0                      NaN                  NaN                 NaN
# 0                    627.0                  NaN                 NaN
# 0                    686.0                 45.0                 NaN
# 0                    519.0                  NaN                 NaN
# 0                   1077.0                 11.0                 D/L
# ..                     ...                  ...                 ...
# 0                    964.0                  NaN                 NaN
# 0                    389.0                 42.0                 NaN
# 0                      NaN                  NaN                 NaN
# 0                      NaN                 18.0                 NaN
# 0                   1015.0                 30.0                 NaN
#
#    info.outcome.result info.outcome.eliminator info.bowl_out  \
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# ..                 ...                     ...           ...
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
#
#    info.outcome.bowl_out  info.supersubs.New Zealand  \
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# ..                   ...                         ...
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
#
#     info.supersubs.South Africa
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
# ..                          ...
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
#
# [1432 rows x 28 columns]

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Nigeria', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
#
#    meta.created  meta.revision      info.city    info.dates info.gender  \
# 0    2012-12-30              2        Belfast  [2008-08-04]        male
# 0    2020-08-08              1      Abu Dhabi  [2017-10-27]        male
# 0    2020-07-06              1            NaN  [2018-07-05]        male
# 0    2020-07-01              1         Guyana  [2018-11-11]      female
# 0    2020-03-06              1  Greater Noida  [2020-03-06]        male
# ..          ...            ...            ...           ...         ...
# 0    2019-10-25              1      Abu Dhabi  [2019-10-24]        male
# 0    2020-08-08              1            NaN  [2017-11-12]      female
# 0    2013-02-20              2       Auckland  [2006-12-26]        male
# 0    2014-05-25              2            NaN  [2012-10-31]      female
# 0    2019-11-14              1        Lucknow  [2019-11-14]        male
#
#    info.match_type  info.neutral_venue  info.outcome.by.wickets  ... match_id  \
# 0              T20                 1.0                      5.0  ...        1
# 0              T20                 NaN                      2.0  ...        2
# 0              T20                 NaN                      NaN  ...        3
# 0              T20                 NaN                      9.0  ...        4
# 0              T20                 NaN                      NaN  ...        5
# ..             ...                 ...                      ...  ...      ...
# 0              T20                 NaN                      5.0  ...     1428
# 0              T20                 NaN                      NaN  ...     1429
# 0              T20                 NaN                      5.0  ...     1430
# 0              T20                 1.0                      NaN  ...     1431
# 0              T20                 NaN                      NaN  ...     1432
#
#     info.match_type_number info.outcome.by.runs info.outcome.method  \
# 0                      NaN                  NaN                 NaN
# 0                    627.0                  NaN                 NaN
# 0                    686.0                 45.0                 NaN
# 0                    519.0                  NaN                 NaN
# 0                   1077.0                 11.0                 D/L
# ..                     ...                  ...                 ...
# 0                    964.0                  NaN                 NaN
# 0                    389.0                 42.0                 NaN
# 0                      NaN                  NaN                 NaN
# 0                      NaN                 18.0                 NaN
# 0                   1015.0                 30.0                 NaN
#
#    info.outcome.result info.outcome.eliminator info.bowl_out  \
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# ..                 ...                     ...           ...
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
# 0                  NaN                     NaN           NaN
#
#    info.outcome.bowl_out  info.supersubs.New Zealand  \
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# ..                   ...                         ...
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
# 0                    NaN                         NaN
#
#     info.supersubs.South Africa
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
# ..                          ...
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
#
# [1432 rows x 28 columns]

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...        Belfast
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...            NaN
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...         Guyana
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Greater Noida
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'Nigeria', 'deliveri...      Abu Dhabi
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...            NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...       Auckland
# 0   [{'1st innings': {'team': 'India', 'deliveries...            NaN
# 0   [{'1st innings': {'team': 'West Indies', 'deli...        Lucknow
#
#       info.dates info.gender info.match_type   info.outcome.winner  \
# 0   [2008-08-04]        male             T20           Netherlands
# 0   [2017-10-27]        male             T20              Pakistan
# 0   [2018-07-05]        male             T20              Pakistan
# 0   [2018-11-11]      female             T20             Australia
# 0   [2020-03-06]        male             T20           Afghanistan
# ..           ...         ...             ...                   ...
# 0   [2019-10-24]        male             T20  United Arab Emirates
# 0   [2017-11-12]      female             T20           New Zealand
# 0   [2006-12-26]        male             T20           New Zealand
# 0   [2012-10-31]      female             T20                 India
# 0   [2019-11-14]        male             T20           West Indies
#
#     info.overs info.player_of_match                       info.teams  \
# 0           20   [RN ten Doeschate]          [Netherlands, Scotland]
# 0           20        [Shadab Khan]            [Sri Lanka, Pakistan]
# 0           20       [Fakhar Zaman]            [Pakistan, Australia]
# 0           20           [AJ Healy]             [Ireland, Australia]
# 0           20        [Rashid Khan]           [Afghanistan, Ireland]
# ..         ...                  ...                              ...
# 0           20        [Zawar Farid]  [United Arab Emirates, Nigeria]
# 0           20           [SW Bates]          [New Zealand, Pakistan]
# 0           20       [JEC Franklin]         [New Zealand, Sri Lanka]
# 0           20            [PG Raut]                [India, Pakistan]
# 0           20         [KA Pollard]       [Afghanistan, West Indies]
#
#    info.toss.decision      info.toss.winner  \
# 0               field           Netherlands
# 0               field              Pakistan
# 0               field             Australia
# 0                 bat               Ireland
# 0                 bat               Ireland
# ..                ...                   ...
# 0               field  United Arab Emirates
# 0                 bat           New Zealand
# 0               field           New Zealand
# 0                 bat                 India
# 0               field           Afghanistan
#
#                                 info.umpires  \
# 0                      [NG Bagh, PK Baldwin]
# 0                [Ahmed Shahab, Shozab Raza]
# 0                      [RB Tiffin, L Rusere]
# 0                     [L Rusere, WR Knights]
# 0   [Bismillah Shinwari, Ahmed Shah Durrani]
# ..                                       ...
# 0                      [LE Hannibal, S Ravi]
# 0              [Khalid Mahmood, Rashid Riaz]
# 0                       [BF Bowden, AL Hill]
# 0                [BB Pradhan, Sarika Prasad]
# 0   [Ahmed Shah Pakteen, Ahmed Shah Durrani]
#
#                                            info.venue  match_id
# 0                Civil Service Cricket Club, Stormont         1
# 0                                Sheikh Zayed Stadium         2
# 0                                  Harare Sports Club         3
# 0                                  Providence Stadium         4
# 0                 Greater Noida Sports Complex Ground         5
# ..                                                ...       ...
# 0                                      Tolerance Oval      1428
# 0                             Sharjah Cricket Stadium      1429
# 0                                           Eden Park      1430
# 0             Guanggong International Cricket Stadium      1431
# 0   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...      1432
#
# [1432 rows x 14 columns]

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...        Belfast
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...            NaN
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Greater Noida
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...        Bangkok
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...      Centurion
# 0   [{'1st innings': {'team': 'South Africa', 'del...   Johannesburg
# 0   [{'1st innings': {'team': 'Nigeria', 'deliveri...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...       Auckland
# 0   [{'1st innings': {'team': 'West Indies', 'deli...        Lucknow
#
#       info.dates info.match_type   info.outcome.winner  info.overs  \
# 0   [2008-08-04]             T20           Netherlands          20
# 0   [2017-10-27]             T20              Pakistan          20
# 0   [2018-07-05]             T20              Pakistan          20
# 0   [2020-03-06]             T20           Afghanistan          20
# 0   [2020-03-01]             T20             Hong Kong          20
# ..           ...             ...                   ...         ...
# 0   [2013-03-03]             T20              Pakistan          20
# 0   [2017-01-22]             T20             Sri Lanka          20
# 0   [2019-10-24]             T20  United Arab Emirates          20
# 0   [2006-12-26]             T20           New Zealand          20
# 0   [2019-11-14]             T20           West Indies          20
#
#    info.player_of_match                       info.teams info.toss.decision  \
# 0    [RN ten Doeschate]          [Netherlands, Scotland]              field
# 0         [Shadab Khan]            [Sri Lanka, Pakistan]              field
# 0        [Fakhar Zaman]            [Pakistan, Australia]              field
# 0         [Rashid Khan]           [Afghanistan, Ireland]                bat
# 0       [Haroon Arshad]               [Hong Kong, Nepal]              field
# ..                  ...                              ...                ...
# 0     [Mohammad Hafeez]         [South Africa, Pakistan]                bat
# 0          [AD Mathews]        [South Africa, Sri Lanka]                bat
# 0         [Zawar Farid]  [United Arab Emirates, Nigeria]              field
# 0        [JEC Franklin]         [New Zealand, Sri Lanka]              field
# 0          [KA Pollard]       [Afghanistan, West Indies]              field
#
#         info.toss.winner                              info.umpires  \
# 0            Netherlands                     [NG Bagh, PK Baldwin]
# 0               Pakistan               [Ahmed Shahab, Shozab Raza]
# 0              Australia                     [RB Tiffin, L Rusere]
# 0                Ireland  [Bismillah Shinwari, Ahmed Shah Durrani]
# 0                  Nepal                  [Arif Ansari, V Kalidas]
# ..                   ...                                       ...
# 0               Pakistan                     [JD Cloete, S George]
# 0           South Africa                   [AT Holdstock, BP Jele]
# 0   United Arab Emirates                     [LE Hannibal, S Ravi]
# 0            New Zealand                      [BF Bowden, AL Hill]
# 0            Afghanistan  [Ahmed Shah Pakteen, Ahmed Shah Durrani]
#
#                                            info.venue  match_id
# 0                Civil Service Cricket Club, Stormont         1
# 0                                Sheikh Zayed Stadium         2
# 0                                  Harare Sports Club         3
# 0                 Greater Noida Sports Complex Ground         5
# 0                             Terdthai Cricket Ground         7
# ..                                                ...       ...
# 0                                     SuperSport Park      1425
# 0                               New Wanderers Stadium      1427
# 0                                      Tolerance Oval      1428
# 0                                           Eden Park      1430
# 0   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...      1432
#
# [966 rows x 13 columns]

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...        Belfast
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...            NaN
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Greater Noida
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...        Bangkok
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...      Centurion
# 0   [{'1st innings': {'team': 'South Africa', 'del...   Johannesburg
# 0   [{'1st innings': {'team': 'Nigeria', 'deliveri...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...       Auckland
# 0   [{'1st innings': {'team': 'West Indies', 'deli...        Lucknow
#
#       info.dates   info.outcome.winner info.player_of_match  \
# 0   [2008-08-04]           Netherlands   [RN ten Doeschate]
# 0   [2017-10-27]              Pakistan        [Shadab Khan]
# 0   [2018-07-05]              Pakistan       [Fakhar Zaman]
# 0   [2020-03-06]           Afghanistan        [Rashid Khan]
# 0   [2020-03-01]             Hong Kong      [Haroon Arshad]
# ..           ...                   ...                  ...
# 0   [2013-03-03]              Pakistan    [Mohammad Hafeez]
# 0   [2017-01-22]             Sri Lanka         [AD Mathews]
# 0   [2019-10-24]  United Arab Emirates        [Zawar Farid]
# 0   [2006-12-26]           New Zealand       [JEC Franklin]
# 0   [2019-11-14]           West Indies         [KA Pollard]
#
#                          info.teams info.toss.decision      info.toss.winner  \
# 0           [Netherlands, Scotland]              field           Netherlands
# 0             [Sri Lanka, Pakistan]              field              Pakistan
# 0             [Pakistan, Australia]              field             Australia
# 0            [Afghanistan, Ireland]                bat               Ireland
# 0                [Hong Kong, Nepal]              field                 Nepal
# ..                              ...                ...                   ...
# 0          [South Africa, Pakistan]                bat              Pakistan
# 0         [South Africa, Sri Lanka]                bat          South Africa
# 0   [United Arab Emirates, Nigeria]              field  United Arab Emirates
# 0          [New Zealand, Sri Lanka]              field           New Zealand
# 0        [Afghanistan, West Indies]              field           Afghanistan
#
#                                 info.umpires  \
# 0                      [NG Bagh, PK Baldwin]
# 0                [Ahmed Shahab, Shozab Raza]
# 0                      [RB Tiffin, L Rusere]
# 0   [Bismillah Shinwari, Ahmed Shah Durrani]
# 0                   [Arif Ansari, V Kalidas]
# ..                                       ...
# 0                      [JD Cloete, S George]
# 0                    [AT Holdstock, BP Jele]
# 0                      [LE Hannibal, S Ravi]
# 0                       [BF Bowden, AL Hill]
# 0   [Ahmed Shah Pakteen, Ahmed Shah Durrani]
#
#                                            info.venue  match_id
# 0                Civil Service Cricket Club, Stormont         1
# 0                                Sheikh Zayed Stadium         2
# 0                                  Harare Sports Club         3
# 0                 Greater Noida Sports Complex Ground         5
# 0                             Terdthai Cricket Ground         7
# ..                                                ...       ...
# 0                                     SuperSport Park      1425
# 0                               New Wanderers Stadium      1427
# 0                                      Tolerance Oval      1428
# 0                                           Eden Park      1430
# 0   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...      1432
#
# [963 rows x 11 columns]

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.3: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.1: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.2: {'batsman': 'KJ Coetzer',
#    'bowler': 'Mudassar Bukhari',
#    'extras': {'legbyes': 1},
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {1.3: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.4: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.5: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.6: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.1: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.2: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.3: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.1: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.2: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.3: {'batsman': 'RR Watson',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {3.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {3.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.1: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.2: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.3: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {4.4: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'E Schiferli',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.6: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'extras': {'wides': 1},
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {4.7: {'batsman': 'RR Watson',
#    'bowler': 'E Schiferli',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.1: {'batsman': 'RR Watson',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.2: {'batsman': 'KJ Coetzer',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.3: {'batsman': 'KJ Coetzer',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {6.1: {'batsman': 'RR Watson',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.2: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.3: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.6: {'batsman': 'RR Watson',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {7.1: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.2: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.3: {'batsman': 'RR Watson',
#    'bowler': 'PM Seelaar',
#    'extras': {'legbyes': 1},
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {7.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.1: {'batsman': 'RR Watson',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.2: {'batsman': 'RR Watson',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.3: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {8.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.1: {'batsman': 'RR Watson',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.2: {'batsman': 'RR Watson',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.3: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.4: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.5: {'batsman': 'RR Watson',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'RR Watson',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.1: {'batsman': 'RR Watson',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'RR Watson'}}},
#  {10.2: {'batsman': 'NS Poonia',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.3: {'batsman': 'NS Poonia',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.4: {'batsman': 'NS Poonia',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {10.5: {'batsman': 'NS Poonia',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.1: {'batsman': 'NS Poonia',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.2: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {11.3: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.4: {'batsman': 'NS Poonia',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.6: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.1: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.2: {'batsman': 'NS Poonia',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.3: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.4: {'batsman': 'NS Poonia',
#    'bowler': 'PW Borren',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'PW Borren',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.6: {'batsman': 'NS Poonia',
#    'bowler': 'PW Borren',
#    'extras': {'legbyes': 1},
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {13.1: {'batsman': 'NS Poonia',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.2: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.3: {'batsman': 'NS Poonia',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.4: {'batsman': 'NS Poonia',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'KJ Coetzer',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.5: {'batsman': 'KJ Coetzer',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['PW Borren', 'PM Seelaar'],
#     'kind': 'run out',
#     'player_out': 'KJ Coetzer'}}},
#  {13.6: {'batsman': 'NS Poonia',
#    'bowler': 'PM Seelaar',
#    'non_striker': 'CJO Smith',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.1: {'batsman': 'NS Poonia',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'CJO Smith',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {14.2: {'batsman': 'NS Poonia',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'CJO Smith',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.3: {'batsman': 'CJO Smith',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['PM Seelaar'],
#     'kind': 'caught',
#     'player_out': 'CJO Smith'}}},
#  {14.4: {'batsman': 'NS Poonia',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.5: {'batsman': 'NS Poonia',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.6: {'batsman': 'GM Hamilton',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.1: {'batsman': 'NS Poonia',
#    'bowler': 'E Schiferli',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.2: {'batsman': 'GM Hamilton',
#    'bowler': 'E Schiferli',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.3: {'batsman': 'NS Poonia',
#    'bowler': 'E Schiferli',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.4: {'batsman': 'GM Hamilton',
#    'bowler': 'E Schiferli',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.5: {'batsman': 'NS Poonia',
#    'bowler': 'E Schiferli',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.6: {'batsman': 'GM Hamilton',
#    'bowler': 'E Schiferli',
#    'extras': {'legbyes': 1},
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {16.1: {'batsman': 'GM Hamilton',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.2: {'batsman': 'GM Hamilton',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {16.3: {'batsman': 'GM Hamilton',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.4: {'batsman': 'NS Poonia',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.5: {'batsman': 'GM Hamilton',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.6: {'batsman': 'NS Poonia',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.1: {'batsman': 'NS Poonia',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {17.2: {'batsman': 'NS Poonia',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.3: {'batsman': 'GM Hamilton',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.4: {'batsman': 'GM Hamilton',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.5: {'batsman': 'NS Poonia',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.6: {'batsman': 'NS Poonia',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'GM Hamilton',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.1: {'batsman': 'GM Hamilton',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['DJ Reekers'],
#     'kind': 'caught',
#     'player_out': 'GM Hamilton'}}},
#  {18.2: {'batsman': 'NS Poonia',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NFI McCallum',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.3: {'batsman': 'NFI McCallum',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['E Schiferli'],
#     'kind': 'caught',
#     'player_out': 'NFI McCallum'}}},
#  {18.4: {'batsman': 'GD Drummond',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'NS Poonia',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['E Schiferli'],
#     'kind': 'run out',
#     'player_out': 'NS Poonia'}}},
#  {18.5: {'batsman': 'RD Berrington',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'GD Drummond',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.6: {'batsman': 'RD Berrington',
#    'bowler': 'RN ten Doeschate',
#    'extras': {'wides': 1},
#    'non_striker': 'GD Drummond',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {18.7: {'batsman': 'RD Berrington',
#    'bowler': 'RN ten Doeschate',
#    'non_striker': 'GD Drummond',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {19.1: {'batsman': 'GD Drummond',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RD Berrington',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.2: {'batsman': 'GD Drummond',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RD Berrington',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {19.3: {'batsman': 'GD Drummond',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RD Berrington',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.4: {'batsman': 'GD Drummond',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RD Berrington',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['J Smits'],
#     'kind': 'run out',
#     'player_out': 'RD Berrington'}}},
#  {19.5: {'batsman': 'JAR Blain',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'GD Drummond',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1},
#    'wicket': {'fielders': ['PW Borren'],
#     'kind': 'run out',
#     'player_out': 'GD Drummond'}}},
#  {19.6: {'batsman': 'JAR Blain',
#    'bowler': 'Mudassar Bukhari',
#    'non_striker': 'RM Haq',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}]

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df
# Out:
#      match_id                       teams batting_team  ball     batsman  \
# 0           2     [Netherlands, Scotland]     Scotland   0.1   RR Watson
# 1           2     [Netherlands, Scotland]     Scotland   0.2   RR Watson
# 2           2     [Netherlands, Scotland]     Scotland   0.3   RR Watson
# 3           2     [Netherlands, Scotland]     Scotland   0.4  KJ Coetzer
# 4           2     [Netherlands, Scotland]     Scotland   0.5  KJ Coetzer
# ..        ...                         ...          ...   ...         ...
# 116       964  [Afghanistan, West Indies]  West Indies  19.2  KA Pollard
# 117       964  [Afghanistan, West Indies]  West Indies  19.3    FA Allen
# 118       964  [Afghanistan, West Indies]  West Indies  19.4  KA Pollard
# 119       964  [Afghanistan, West Indies]  West Indies  19.5  KA Pollard
# 120       964  [Afghanistan, West Indies]  West Indies  19.6  KA Pollard
#
#             bowler  runs player_dismissed     city  \
# 0      E Schiferli     0                0  Belfast
# 1      E Schiferli     2                0  Belfast
# 2      E Schiferli     1                0  Belfast
# 3      E Schiferli     0                0  Belfast
# 4      E Schiferli     2                0  Belfast
# ..             ...   ...              ...      ...
# 116  Naveen-ul-Haq     1                0  Lucknow
# 117  Naveen-ul-Haq     1                0  Lucknow
# 118  Naveen-ul-Haq     2                0  Lucknow
# 119  Naveen-ul-Haq     6                0  Lucknow
# 120  Naveen-ul-Haq     4                0  Lucknow
#
#                                                  venue
# 0                 Civil Service Cricket Club, Stormont
# 1                 Civil Service Cricket Club, Stormont
# 2                 Civil Service Cricket Club, Stormont
# 3                 Civil Service Cricket Club, Stormont
# 4                 Civil Service Cricket Club, Stormont
# ..                                                 ...
# 116  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 117  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 118  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 119  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 120  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
# [115302 rows x 10 columns]

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                       teams batting_team  ball     batsman  \
# 0           2     [Netherlands, Scotland]     Scotland   0.1   RR Watson
# 1           2     [Netherlands, Scotland]     Scotland   0.2   RR Watson
# 2           2     [Netherlands, Scotland]     Scotland   0.3   RR Watson
# 3           2     [Netherlands, Scotland]     Scotland   0.4  KJ Coetzer
# 4           2     [Netherlands, Scotland]     Scotland   0.5  KJ Coetzer
# ..        ...                         ...          ...   ...         ...
# 116       964  [Afghanistan, West Indies]  West Indies  19.2  KA Pollard
# 117       964  [Afghanistan, West Indies]  West Indies  19.3    FA Allen
# 118       964  [Afghanistan, West Indies]  West Indies  19.4  KA Pollard
# 119       964  [Afghanistan, West Indies]  West Indies  19.5  KA Pollard
# 120       964  [Afghanistan, West Indies]  West Indies  19.6  KA Pollard
#
#             bowler  runs player_dismissed     city  \
# 0      E Schiferli     0                0  Belfast
# 1      E Schiferli     2                0  Belfast
# 2      E Schiferli     1                0  Belfast
# 3      E Schiferli     0                0  Belfast
# 4      E Schiferli     2                0  Belfast
# ..             ...   ...              ...      ...
# 116  Naveen-ul-Haq     1                0  Lucknow
# 117  Naveen-ul-Haq     1                0  Lucknow
# 118  Naveen-ul-Haq     2                0  Lucknow
# 119  Naveen-ul-Haq     6                0  Lucknow
# 120  Naveen-ul-Haq     4                0  Lucknow
#
#                                                  venue bowling_team
# 0                 Civil Service Cricket Club, Stormont  Netherlands
# 1                 Civil Service Cricket Club, Stormont  Netherlands
# 2                 Civil Service Cricket Club, Stormont  Netherlands
# 3                 Civil Service Cricket Club, Stormont  Netherlands
# 4                 Civil Service Cricket Club, Stormont  Netherlands
# ..                                                 ...          ...
# 116  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 117  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 118  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 119  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 120  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
#
# [115302 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Scotland', 'Sri Lanka', 'Pakistan', 'Ireland', 'Hong Kong',
#        'Australia', 'South Africa', 'Kenya', 'Papua New Guinea',
#        'West Indies', 'Malaysia', 'United States of America', 'England',
#        'Cayman Islands', 'Bermuda', 'Kuwait', 'India', 'Zimbabwe',
#        'New Zealand', 'United Arab Emirates', 'Bangladesh', 'Namibia',
#        'Bulgaria', 'Denmark', 'Afghanistan', 'Nepal', 'Netherlands',
#        'Singapore', 'Isle of Man', 'Thailand', 'Canada', 'Norway',
#        'Vanuatu', 'Germany', 'Jersey', 'Oman', 'Nigeria', 'Gibraltar',
#        'Ghana', 'Maldives', 'Guernsey', 'Philippines', 'Portugal',
#        'Uganda', 'Botswana', 'Bhutan', 'Belgium', 'Spain', 'Iran',
#        'Romania', 'Italy', 'Qatar'], dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball         batsman         bowler  runs  \
# 0           3    Sri Lanka   0.1  MD Gunathilaka     Imad Wasim     0
# 1           3    Sri Lanka   0.2  MD Gunathilaka     Imad Wasim     0
# 2           3    Sri Lanka   0.3  MD Gunathilaka     Imad Wasim     1
# 3           3    Sri Lanka   0.4  EMDY Munaweera     Imad Wasim     0
# 4           3    Sri Lanka   0.5  EMDY Munaweera     Imad Wasim     0
# ..        ...          ...   ...             ...            ...   ...
# 116       964  West Indies  19.2      KA Pollard  Naveen-ul-Haq     1
# 117       964  West Indies  19.3        FA Allen  Naveen-ul-Haq     1
# 118       964  West Indies  19.4      KA Pollard  Naveen-ul-Haq     2
# 119       964  West Indies  19.5      KA Pollard  Naveen-ul-Haq     6
# 120       964  West Indies  19.6      KA Pollard  Naveen-ul-Haq     4
#
#     player_dismissed       city  \
# 0                  0  Abu Dhabi
# 1                  0  Abu Dhabi
# 2                  0  Abu Dhabi
# 3                  0  Abu Dhabi
# 4                  0  Abu Dhabi
# ..               ...        ...
# 116                0    Lucknow
# 117                0    Lucknow
# 118                0    Lucknow
# 119                0    Lucknow
# 120                0    Lucknow
#
#                                                  venue bowling_team
# 0                                 Sheikh Zayed Stadium     Pakistan
# 1                                 Sheikh Zayed Stadium     Pakistan
# 2                                 Sheikh Zayed Stadium     Pakistan
# 3                                 Sheikh Zayed Stadium     Pakistan
# 4                                 Sheikh Zayed Stadium     Pakistan
# ..                                                 ...          ...
# 116  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 117  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 118  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 119  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
# 120  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Afghanistan
#
# [64128 rows x 10 columns]

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           3    Sri Lanka     Pakistan   0.1     0                0
# 1           3    Sri Lanka     Pakistan   0.2     0                0
# 2           3    Sri Lanka     Pakistan   0.3     1                0
# 3           3    Sri Lanka     Pakistan   0.4     0                0
# 4           3    Sri Lanka     Pakistan   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 116       964  West Indies  Afghanistan  19.2     1                0
# 117       964  West Indies  Afghanistan  19.3     1                0
# 118       964  West Indies  Afghanistan  19.4     2                0
# 119       964  West Indies  Afghanistan  19.5     6                0
# 120       964  West Indies  Afghanistan  19.6     4                0
#
#           city                                              venue
# 0    Abu Dhabi                               Sheikh Zayed Stadium
# 1    Abu Dhabi                               Sheikh Zayed Stadium
# 2    Abu Dhabi                               Sheikh Zayed Stadium
# 3    Abu Dhabi                               Sheikh Zayed Stadium
# 4    Abu Dhabi                               Sheikh Zayed Stadium
# ..         ...                                                ...
# 116    Lucknow  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 117    Lucknow  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 118    Lucknow  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 119    Lucknow  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 120    Lucknow  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
# [64128 rows x 8 columns]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
output[output['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       627
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
x = np.where(output['city'].isnull(), output['venue'].str.split().apply(lambda x:x[0]), output['city'])

# %%
output['city'] = x
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
output.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
output.drop(columns=['venue'],inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           3    Sri Lanka     Pakistan   0.1     0                0
# 1           3    Sri Lanka     Pakistan   0.2     0                0
# 2           3    Sri Lanka     Pakistan   0.3     1                0
# 3           3    Sri Lanka     Pakistan   0.4     0                0
# 4           3    Sri Lanka     Pakistan   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 116       964  West Indies  Afghanistan  19.2     1                0
# 117       964  West Indies  Afghanistan  19.3     1                0
# 118       964  West Indies  Afghanistan  19.4     2                0
# 119       964  West Indies  Afghanistan  19.5     6                0
# 120       964  West Indies  Afghanistan  19.6     4                0
#
#           city
# 0    Abu Dhabi
# 1    Abu Dhabi
# 2    Abu Dhabi
# 3    Abu Dhabi
# 4    Abu Dhabi
# ..         ...
# 116    Lucknow
# 117    Lucknow
# 118    Lucknow
# 119    Lucknow
# 120    Lucknow
#
# [64128 rows x 7 columns]

# %%
total_df = output.groupby('match_id').sum()['runs'].reset_index()
output = output.merge(total_df,on='match_id')

# %%
output
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             3    Sri Lanka     Pakistan   0.1       0                0
# 1             3    Sri Lanka     Pakistan   0.2       0                0
# 2             3    Sri Lanka     Pakistan   0.3       1                0
# 3             3    Sri Lanka     Pakistan   0.4       0                0
# 4             3    Sri Lanka     Pakistan   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 64123       964  West Indies  Afghanistan  19.2       1                0
# 64124       964  West Indies  Afghanistan  19.3       1                0
# 64125       964  West Indies  Afghanistan  19.4       2                0
# 64126       964  West Indies  Afghanistan  19.5       6                0
# 64127       964  West Indies  Afghanistan  19.6       4                0
#
#             city  runs_y
# 0      Abu Dhabi     124
# 1      Abu Dhabi     124
# 2      Abu Dhabi     124
# 3      Abu Dhabi     124
# 4      Abu Dhabi     124
# ...          ...     ...
# 64123    Lucknow     164
# 64124    Lucknow     164
# 64125    Lucknow     164
# 64126    Lucknow     164
# 64127    Lucknow     164
#
# [64128 rows x 8 columns]

# %%
output['current_score'] = output.groupby('match_id').cumsum()['runs_x']

# %%
output['over'] = output['ball'].apply(lambda x:str(x).split(".")[0])
output['ball_no'] = output['ball'].apply(lambda x:str(x).split(".")[1])

# %%
output['balls_bowled'] = (output['over'].astype('int')*6) + output['ball_no'].astype('int')

# %%
output['crr'] = round((output['current_score']*6)/output['balls_bowled'],2)

# %%
output['player_dismissed'] = output['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
output['player_dismissed'] = output['player_dismissed'].astype('int')
output['player_dismissed'] = output.groupby('match_id').cumsum()['player_dismissed']
output['wickets_left'] = 10 - output['player_dismissed']

# %%
final_df = output[['match_id','batting_team','bowling_team','runs_x','current_score','balls_bowled','wickets_left','crr','city','runs_y']]

# %%
final_df
# Out:
#        match_id batting_team bowling_team  runs_x  current_score  \
# 0             3    Sri Lanka     Pakistan       0              0
# 1             3    Sri Lanka     Pakistan       0              0
# 2             3    Sri Lanka     Pakistan       1              1
# 3             3    Sri Lanka     Pakistan       0              1
# 4             3    Sri Lanka     Pakistan       0              1
# ...         ...          ...          ...     ...            ...
# 64123       964  West Indies  Afghanistan       1            151
# 64124       964  West Indies  Afghanistan       1            152
# 64125       964  West Indies  Afghanistan       2            154
# 64126       964  West Indies  Afghanistan       6            160
# 64127       964  West Indies  Afghanistan       4            164
#
#        balls_bowled  wickets_left   crr       city  runs_y
# 0                 1            10  0.00  Abu Dhabi     124
# 1                 2            10  0.00  Abu Dhabi     124
# 2                 3            10  2.00  Abu Dhabi     124
# 3                 4            10  1.50  Abu Dhabi     124
# 4                 5            10  1.20  Abu Dhabi     124
# ...             ...           ...   ...        ...     ...
# 64123           116             5  7.81    Lucknow     164
# 64124           117             5  7.79    Lucknow     164
# 64125           118             5  7.83    Lucknow     164
# 64126           119             5  8.07    Lucknow     164
# 64127           120             5  8.20    Lucknow     164
#
# [64128 rows x 10 columns]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df['balls_left'] = 120 - final_df['balls_bowled']
final_df['balls_left'] = final_df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
final_df['crr'] = round((final_df['current_score']*6)/final_df['balls_bowled'],2)

# %%
final_df
# Out:
#        match_id  batting_team bowling_team  runs_x  current_score  \
# 43964       667    Bangladesh  West Indies       0              5
# 14081       225  South Africa    Sri Lanka       1             82
# 58733       885     Sri Lanka   Bangladesh       0             37
# 49532       744       England  New Zealand       1            156
# 32664       492   New Zealand    Australia       0            212
# ...         ...           ...          ...     ...            ...
# 28281       427   New Zealand     Pakistan       1             51
# 16008       255  South Africa  West Indies       0            130
# 12980       210   West Indies      England       0              5
# 9987        153      Pakistan    Sri Lanka       1            148
# 52780       787    Bangladesh     Pakistan       1             58
#
#        balls_bowled  wickets_left    crr          city  runs_y  balls_left
# 43964             4             8   7.50      St Kitts     143         116
# 14081            97             6   5.07       Colombo     115          23
# 58733            30             9   7.40  Johannesburg     147          90
# 49532           103             5   9.09    Manchester     191          17
# 32664           102             7  12.47      Auckland     243          18
# ...             ...           ...    ...           ...     ...         ...
# 28281            37             9   8.27         Dubai     153          83
# 16008            68             7  11.47  Johannesburg     231          52
# 12980             6            10   5.00    Gros Islet     160         114
# 9987            109             8   8.15        Lahore     180          11
# 52780            61             7   5.70        Lahore     136          59
#
# [64128 rows x 11 columns]

# %%
final_df.drop(columns=['balls_bowled'],inplace=True)

# %%
groups = final_df.groupby('match_id')

# %%
match_ids = final_df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs_x'].values.tolist())

# %%
final_df['last_five'] = last_five

# %%
final_df
# Out:
#        match_id  batting_team bowling_team  runs_x  current_score  \
# 43964       667    Bangladesh  West Indies       0              5
# 14081       225  South Africa    Sri Lanka       1             82
# 58733       885     Sri Lanka   Bangladesh       0             37
# 49532       744       England  New Zealand       1            156
# 32664       492   New Zealand    Australia       0            212
# ...         ...           ...          ...     ...            ...
# 28281       427   New Zealand     Pakistan       1             51
# 16008       255  South Africa  West Indies       0            130
# 12980       210   West Indies      England       0              5
# 9987        153      Pakistan    Sri Lanka       1            148
# 52780       787    Bangladesh     Pakistan       1             58
#
#        wickets_left    crr          city  runs_y  balls_left  last_five
# 43964             8   7.50      St Kitts     143         116        NaN
# 14081             6   5.07       Colombo     115          23        NaN
# 58733             9   7.40  Johannesburg     147          90        NaN
# 49532             5   9.09    Manchester     191          17        NaN
# 32664             7  12.47      Auckland     243          18        NaN
# ...             ...    ...           ...     ...         ...        ...
# 28281             9   8.27         Dubai     153          83       40.0
# 16008             7  11.47  Johannesburg     231          52       40.0
# 12980            10   5.00    Gros Islet     160         114       40.0
# 9987              8   8.15        Lahore     180          11        NaN
# 52780             7   5.70        Lahore     136          59        NaN
#
# [64128 rows x 11 columns]

# %%
final_df.dropna(inplace=True)

# %%
final_df
# Out:
#        match_id  batting_team  bowling_team  runs_x  current_score  \
# 42760       649     Sri Lanka         India       1             76
# 47929       724  South Africa    Bangladesh       0             95
# 57517       854   New Zealand      Pakistan       0             92
# 26387       404      Pakistan    Bangladesh       0             28
# 926          17     Australia  South Africa       1             87
# ...         ...           ...           ...     ...            ...
# 34306       517  South Africa     Australia       1            146
# 47857       722   New Zealand  South Africa       0            167
# 28281       427   New Zealand      Pakistan       1             51
# 16008       255  South Africa   West Indies       0            130
# 12980       210   West Indies       England       0              5
#
#        wickets_left    crr          city  runs_y  balls_left  last_five
# 42760             9   8.14       Colombo     171          64       36.0
# 47929             9   9.05        Mirpur     169          57       36.0
# 57517             8   7.89      Hamilton     185          50       37.0
# 26387             8   7.64       Karachi     203          98       32.0
# 926               9   9.00      Brisbane     209          62       28.0
# ...             ...    ...           ...     ...         ...        ...
# 34306             3   7.30     Cape Town     146           0       43.0
# 47857             3   8.79     Centurion     177           6       44.0
# 28281             9   8.27         Dubai     153          83       40.0
# 16008             7  11.47  Johannesburg     231          52       40.0
# 12980            10   5.00    Gros Islet     160         114       40.0
#
# [48827 rows x 11 columns]

# %%
eligible_cities = final_df['city'].value_counts()[final_df['city'].value_counts() > 600].index.tolist()
final_df = final_df[final_df['city'].isin(eligible_cities)]

# %%
X = final_df.drop(columns=['match_id','runs_x','runs_y'])
y = final_df['runs_y']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_test
# Out:
#        batting_team  bowling_team  current_score  wickets_left    crr  \
# 58766     Sri Lanka    Bangladesh             63             7   6.10
# 37113       England   West Indies             84            10   9.33
# 43464      Pakistan   New Zealand             11            10   9.43
# 20014  South Africa         India            103             4   6.44
# 30759   New Zealand  South Africa             23             7   4.06
# ...             ...           ...            ...           ...    ...
# 37644     Sri Lanka         India             84             6   5.93
# 17119       England   New Zealand             85             8   8.50
# 28171    Bangladesh     Sri Lanka             53             7   6.12
# 63773  South Africa     Sri Lanka              4            10   8.00
# 21446  South Africa       England             58            10  10.88
#
#                   city  balls_left  last_five
# 58766     Johannesburg          58       37.0
# 37113         Barbados          66       47.0
# 43464  Mount Maunganui         113       49.0
# 20014     Johannesburg          24       42.0
# 30759           Durban          86       47.0
# ...                ...         ...        ...
# 37644           Mirpur          35       27.0
# 17119         Hamilton          60       42.0
# 28171           Mirpur          68       40.0
# 63773     Johannesburg         117       51.0
# 21446        Centurion          88       55.0
#
# [6753 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9505688174193447
# 3.1336021008146226

# %%
teams
# Out:
# ['Australia',
#  'India',
#  'Bangladesh',
#  'New Zealand',
#  'South Africa',
#  'England',
#  'West Indies',
#  'Afghanistan',
#  'Pakistan',
#  'Sri Lanka']

# %%
# os.remove("/kaggle/working/")
pickle.dump(pipe,open('pipe.pkl','wb'))
